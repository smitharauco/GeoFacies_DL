# %%
from Model.DCVAE import DCVAE_Inc
from Model.Utils import LoadMPS45,PlotHistory,PlotDataAE
from keras.utils import to_categorical
from keras.optimizers import RMSprop,Adam
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
x_train1,x_test1=LoadMPS45(dirBase='DataSet/MPS-45.mat',AllTrain=True);
x_train=to_categorical(x_train1,2)
x_test=to_categorical(x_test1,2)
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

# %%
model = DCVAE_Inc(input_shape=(45,45,2),kernel_init=32,latent_dim=500,drop=0,opt= RMSprop(),scheduler=True) # Adam(amsgrad=True)

# %%
model.fit(x_train, num_epochs=500,batch_size=64,val_split=0.2,verbose=1)
# Out:
# Setting up model...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 45, 45, 2)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 45, 45, 32)   96          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 45, 45, 16)   528         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 45, 45, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 45, 45, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 45, 45, 32)   544         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 45, 45, 32)   4640        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 45, 45, 32)   12832       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 45, 45, 32)   25120       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 45, 45, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 45, 45, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 45, 45, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 45, 45, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 45, 45, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 45, 45, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 45, 45, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 45, 45, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 45, 45, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 45, 45, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 45, 45, 32)   0           activation_2[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
#                                                                  activation_5[0][0]
#                                                                  max_pooling2d_1[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 22, 22, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 22, 22, 64)   2112        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 22, 22, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 22, 22, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 22, 22, 32)   2080        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 22, 22, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 22, 22, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 22, 22, 64)   2112        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 22, 22, 64)   18496       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 22, 22, 64)   51264       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 22, 22, 64)   100416      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 22, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 22, 22, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 22, 22, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 22, 22, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 22, 22, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 22, 22, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 22, 22, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 22, 22, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 22, 22, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 22, 22, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 22, 22, 64)   0           activation_8[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  max_pooling2d_3[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 11, 11, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 11, 11, 128)  8320        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 11, 11, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 11, 11, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 11, 11, 64)   8256        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 11, 11, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 11, 11, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 11, 11, 128)  8320        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 11, 11, 128)  73856       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 11, 11, 128)  204928      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 11, 11, 128)  401536      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 11, 11, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 11, 11, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 11, 11, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 11, 11, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 11, 11, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 11, 11, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 11, 11, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 11, 11, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 11, 11, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 11, 11, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 11, 11, 128)  0           activation_14[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_16[0][0]
#                                                                  activation_17[0][0]
#                                                                  max_pooling2d_5[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 2, 2, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 256)    33024       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 2, 2, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2, 2, 256)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 128)    32896       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 2, 2, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2, 2, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 256)    33024       activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 256)    295168      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 256)    819456      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 256)    1605888     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 2, 2, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 2, 2, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 2, 2, 256)    1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 2, 2, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 2, 2, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2, 2, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2, 2, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 2, 2, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 2, 2, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 2, 2, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2, 2, 256)    0           activation_20[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_23[0][0]
#                                                                  max_pooling2d_7[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 256)       0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 256)          0           lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 500)          128500      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 500)          128500      dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 500)          0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          128256      lambda_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 256)       0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 256)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 3, 3, 256)    0           lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 3, 3, 128)    32896       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 3, 3, 128)    512         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 3, 3, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 3, 3, 256)    33024       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 3, 3, 256)    295168      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 3, 3, 256)    819456      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 3, 3, 256)    1605888     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 3, 3, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 3, 3, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 3, 3, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 256)    0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 3, 3, 256)    0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 3, 3, 256)    0           activation_25[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_28[0][0]
#                                                                  max_pooling2d_9[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 12, 12, 128)  524416      add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 12, 12, 64)   8256        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 64)   256         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 12, 12, 128)  8320        activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 12, 12, 128)  73856       activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 12, 12, 128)  204928      activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 12, 12, 128)  401536      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 12, 12, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 12, 12, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 12, 128)  0           activation_31[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_34[0][0]
#                                                                  max_pooling2d_11[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 24, 24, 64)   32832       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 24, 24, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 24, 24, 32)   2080        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 24, 24, 32)   128         conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 24, 24, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 24, 24, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 24, 24, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 24, 24, 64)   51264       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 24, 24, 64)   100416      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 24, 24, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 24, 24, 64)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 24, 24, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 24, 24, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 24, 24, 64)   0           activation_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 24, 24, 64)   0           activation_35[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 24, 24, 64)   0           activation_37[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  max_pooling2d_13[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 48, 48, 32)   8224        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 48, 48, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 48, 48, 16)   528         activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 48, 48, 16)   64          conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 48, 48, 16)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 48, 48, 32)   544         activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 48, 48, 32)   4640        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 48, 48, 32)   12832       activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 48, 48, 32)   25120       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 48, 48, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 48, 48, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 48, 48, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 48, 48, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 48, 48, 32)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 48, 48, 32)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 48, 48, 32)   0           activation_43[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_46[0][0]
#                                                                  max_pooling2d_15[0][0]
#                                                                  max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_1 (Bilinear (None, 45, 45, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 45, 45, 2)    66          bilinear_upsampling_1[0][0]
# ==================================================================================================
# Total params: 8,417,034
# Trainable params: 8,407,050
# Non-trainable params: 9,984
# __________________________________________________________________________________________________
# Completed model setup.
# Train on 23997 samples, validate on 6000 samples
# HBox(children=(IntProgress(value=0, description='Training', max=500, style=ProgressStyle(description_width='in…
# Epoch 1/500
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 65s 3ms/step - loss: 5303.3072 - acc_pred: 0.7939 - val_loss: 3571.9358 - val_acc_pred: 0.6860
# Epoch 2/500
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 675.9245 - acc_pred: 0.8805 - val_loss: 851.0132 - val_acc_pred: 0.8583
# Epoch 3/500
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 570.3346 - acc_pred: 0.8992 - val_loss: 638.4365 - val_acc_pred: 0.8883
# Epoch 4/500
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 515.6069 - acc_pred: 0.9088 - val_loss: 547.5809 - val_acc_pred: 0.9046
# Epoch 5/500
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 477.1743 - acc_pred: 0.9157 - val_loss: 472.1001 - val_acc_pred: 0.9171
# Epoch 6/500
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 443.1329 - acc_pred: 0.9218 - val_loss: 448.8969 - val_acc_pred: 0.9190
# Epoch 7/500
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 414.4250 - acc_pred: 0.9268 - val_loss: 461.7677 - val_acc_pred: 0.9184
# Epoch 8/500
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 60s 2ms/step - loss: 389.3935 - acc_pred: 0.9312 - val_loss: 417.0782 - val_acc_pred: 0.9233
# Epoch 9/500
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 369.4698 - acc_pred: 0.9347 - val_loss: 383.3738 - val_acc_pred: 0.9325
# Epoch 10/500
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=23997, style=ProgressStyle(description_width='i…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 353.5804 - acc_pred: 0.9376 - val_loss: 422.1791 - val_acc_pred: 0.9242
# Epoch 11/500
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 341.5666 - acc_pred: 0.9398 - val_loss: 359.5376 - val_acc_pred: 0.9364
# Epoch 12/500
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 332.0776 - acc_pred: 0.9416 - val_loss: 378.6091 - val_acc_pred: 0.9328
# Epoch 13/500
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 323.3340 - acc_pred: 0.9434 - val_loss: 347.9064 - val_acc_pred: 0.9395
# Epoch 14/500
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 316.0306 - acc_pred: 0.9448 - val_loss: 352.4354 - val_acc_pred: 0.9385
# Epoch 15/500
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 310.7563 - acc_pred: 0.9459 - val_loss: 336.7685 - val_acc_pred: 0.9412
# Epoch 16/500
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 304.7540 - acc_pred: 0.9471 - val_loss: 318.9091 - val_acc_pred: 0.9452
# Epoch 17/500
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 300.9048 - acc_pred: 0.9480 - val_loss: 305.0621 - val_acc_pred: 0.9469
# Epoch 18/500
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 296.1130 - acc_pred: 0.9490 - val_loss: 355.8602 - val_acc_pred: 0.9391
# Epoch 19/500
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 292.5782 - acc_pred: 0.9498 - val_loss: 320.5653 - val_acc_pred: 0.9445
# Epoch 20/500
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 280.4307 - acc_pred: 0.9524 - val_loss: 305.2817 - val_acc_pred: 0.9470
# Epoch 21/500
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 277.7316 - acc_pred: 0.9530 - val_loss: 294.0700 - val_acc_pred: 0.9491
# Epoch 22/500
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 274.6947 - acc_pred: 0.9536 - val_loss: 302.5211 - val_acc_pred: 0.9482
# Epoch 23/500
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 272.3933 - acc_pred: 0.9542 - val_loss: 291.4919 - val_acc_pred: 0.9511
# Epoch 24/500
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 270.2360 - acc_pred: 0.9546 - val_loss: 276.8961 - val_acc_pred: 0.9533
# Epoch 25/500
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 267.7469 - acc_pred: 0.9552 - val_loss: 285.7360 - val_acc_pred: 0.9516
# Epoch 26/500
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 266.3945 - acc_pred: 0.9555 - val_loss: 280.7972 - val_acc_pred: 0.9529
# Epoch 27/500
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 264.2811 - acc_pred: 0.9560 - val_loss: 287.7278 - val_acc_pred: 0.9511
# Epoch 28/500
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 262.3607 - acc_pred: 0.9564 - val_loss: 294.1825 - val_acc_pred: 0.9499
# ...
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 8.000000525498763e-05.
# Epoch 47/500
# HBox(children=(IntProgress(value=0, description='Epoch 46', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 224.8668 - acc_pred: 0.9648 - val_loss: 243.4076 - val_acc_pred: 0.9612
# Epoch 48/500
# HBox(children=(IntProgress(value=0, description='Epoch 47', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 223.9502 - acc_pred: 0.9650 - val_loss: 243.2087 - val_acc_pred: 0.9614
# Epoch 49/500
# HBox(children=(IntProgress(value=0, description='Epoch 48', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 223.6207 - acc_pred: 0.9651 - val_loss: 243.1935 - val_acc_pred: 0.9613
# Epoch 50/500
# HBox(children=(IntProgress(value=0, description='Epoch 49', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 223.4283 - acc_pred: 0.9651 - val_loss: 242.9046 - val_acc_pred: 0.9615
# Epoch 51/500
# HBox(children=(IntProgress(value=0, description='Epoch 50', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 223.2471 - acc_pred: 0.9652 - val_loss: 243.8339 - val_acc_pred: 0.9613
# Epoch 52/500
# HBox(children=(IntProgress(value=0, description='Epoch 51', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 223.0843 - acc_pred: 0.9653 - val_loss: 243.0239 - val_acc_pred: 0.9615
# Epoch 53/500
# HBox(children=(IntProgress(value=0, description='Epoch 52', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 222.6425 - acc_pred: 0.9653 - val_loss: 242.8103 - val_acc_pred: 0.9614
# Epoch 54/500
# HBox(children=(IntProgress(value=0, description='Epoch 53', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 222.4885 - acc_pred: 0.9654 - val_loss: 243.1589 - val_acc_pred: 0.9615
# Epoch 55/500
# HBox(children=(IntProgress(value=0, description='Epoch 54', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 222.5607 - acc_pred: 0.9654 - val_loss: 243.7342 - val_acc_pred: 0.9613
# Epoch 56/500
# HBox(children=(IntProgress(value=0, description='Epoch 55', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 222.2308 - acc_pred: 0.9655 - val_loss: 243.6283 - val_acc_pred: 0.9614
# Epoch 57/500
# HBox(children=(IntProgress(value=0, description='Epoch 56', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 221.7434 - acc_pred: 0.9656 - val_loss: 244.0594 - val_acc_pred: 0.9613
# Epoch 58/500
# HBox(children=(IntProgress(value=0, description='Epoch 57', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 221.5364 - acc_pred: 0.9656 - val_loss: 243.7202 - val_acc_pred: 0.9614
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 4.0000002627493814e-05.
# Epoch 59/500
# HBox(children=(IntProgress(value=0, description='Epoch 58', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 220.9701 - acc_pred: 0.9657 - val_loss: 242.7150 - val_acc_pred: 0.9618
# Epoch 60/500
# HBox(children=(IntProgress(value=0, description='Epoch 59', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 220.3764 - acc_pred: 0.9659 - val_loss: 242.5920 - val_acc_pred: 0.9617
# Epoch 61/500
# HBox(children=(IntProgress(value=0, description='Epoch 60', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 220.2442 - acc_pred: 0.9659 - val_loss: 242.8496 - val_acc_pred: 0.9616
# Epoch 62/500
# HBox(children=(IntProgress(value=0, description='Epoch 61', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 220.2572 - acc_pred: 0.9659 - val_loss: 242.7686 - val_acc_pred: 0.9617
# Epoch 63/500
# HBox(children=(IntProgress(value=0, description='Epoch 62', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 220.0022 - acc_pred: 0.9660 - val_loss: 242.5653 - val_acc_pred: 0.9617
# Epoch 64/500
# HBox(children=(IntProgress(value=0, description='Epoch 63', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 219.9114 - acc_pred: 0.9660 - val_loss: 242.7914 - val_acc_pred: 0.9617
# Epoch 65/500
# HBox(children=(IntProgress(value=0, description='Epoch 64', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 219.7733 - acc_pred: 0.9660 - val_loss: 242.4240 - val_acc_pred: 0.9618
# Epoch 66/500
# HBox(children=(IntProgress(value=0, description='Epoch 65', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 219.8405 - acc_pred: 0.9660 - val_loss: 242.4448 - val_acc_pred: 0.9617
# Epoch 67/500
# HBox(children=(IntProgress(value=0, description='Epoch 66', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 219.6211 - acc_pred: 0.9661 - val_loss: 242.6659 - val_acc_pred: 0.9617
# Epoch 68/500
# HBox(children=(IntProgress(value=0, description='Epoch 67', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 219.4560 - acc_pred: 0.9661 - val_loss: 242.4904 - val_acc_pred: 0.9618
# Epoch 69/500
# HBox(children=(IntProgress(value=0, description='Epoch 68', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 219.3758 - acc_pred: 0.9661 - val_loss: 242.6760 - val_acc_pred: 0.9617
# Epoch 70/500
# HBox(children=(IntProgress(value=0, description='Epoch 69', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 219.2171 - acc_pred: 0.9662 - val_loss: 243.0085 - val_acc_pred: 0.9617
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-05.
# Epoch 71/500
# HBox(children=(IntProgress(value=0, description='Epoch 70', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 218.7553 - acc_pred: 0.9663 - val_loss: 242.5539 - val_acc_pred: 0.9618
# Epoch 72/500
# HBox(children=(IntProgress(value=0, description='Epoch 71', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 218.9246 - acc_pred: 0.9662 - val_loss: 242.6283 - val_acc_pred: 0.9618
# Epoch 73/500
# HBox(children=(IntProgress(value=0, description='Epoch 72', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 218.7671 - acc_pred: 0.9663 - val_loss: 242.6736 - val_acc_pred: 0.9618
# Epoch 74/500
# HBox(children=(IntProgress(value=0, description='Epoch 73', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 218.8433 - acc_pred: 0.9662 - val_loss: 242.5163 - val_acc_pred: 0.9619
# Epoch 75/500
# HBox(children=(IntProgress(value=0, description='Epoch 74', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 218.7497 - acc_pred: 0.9663 - val_loss: 242.3802 - val_acc_pred: 0.9618
# Epoch 76/500
# HBox(children=(IntProgress(value=0, description='Epoch 75', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 218.7117 - acc_pred: 0.9663 - val_loss: 242.5519 - val_acc_pred: 0.9618
# Epoch 77/500
# HBox(children=(IntProgress(value=0, description='Epoch 76', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 218.4712 - acc_pred: 0.9664 - val_loss: 242.3768 - val_acc_pred: 0.9619
# Epoch 78/500
# HBox(children=(IntProgress(value=0, description='Epoch 77', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 218.5434 - acc_pred: 0.9663 - val_loss: 242.8240 - val_acc_pred: 0.9618
# Epoch 79/500
# HBox(children=(IntProgress(value=0, description='Epoch 78', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 218.5572 - acc_pred: 0.9663 - val_loss: 242.4771 - val_acc_pred: 0.9619
# Epoch 80/500
# HBox(children=(IntProgress(value=0, description='Epoch 79', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 218.7068 - acc_pred: 0.9663 - val_loss: 242.5983 - val_acc_pred: 0.9619
# Epoch 81/500
# HBox(children=(IntProgress(value=0, description='Epoch 80', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 218.3236 - acc_pred: 0.9664 - val_loss: 242.7703 - val_acc_pred: 0.9618
# Epoch 82/500
# HBox(children=(IntProgress(value=0, description='Epoch 81', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 218.5041 - acc_pred: 0.9664 - val_loss: 242.4207 - val_acc_pred: 0.9619
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-06.
# Epoch 83/500
# HBox(children=(IntProgress(value=0, description='Epoch 82', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 217.9688 - acc_pred: 0.9665 - val_loss: 242.3067 - val_acc_pred: 0.9619
# Epoch 84/500
# HBox(children=(IntProgress(value=0, description='Epoch 83', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 59s 2ms/step - loss: 218.0624 - acc_pred: 0.9664 - val_loss: 242.4129 - val_acc_pred: 0.9619
# Epoch 85/500
# HBox(children=(IntProgress(value=0, description='Epoch 84', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 60s 3ms/step - loss: 218.2395 - acc_pred: 0.9664 - val_loss: 242.2085 - val_acc_pred: 0.9620
# Epoch 86/500
# HBox(children=(IntProgress(value=0, description='Epoch 85', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 218.1561 - acc_pred: 0.9664 - val_loss: 242.7360 - val_acc_pred: 0.9619
# Epoch 87/500
# HBox(children=(IntProgress(value=0, description='Epoch 86', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 217.9948 - acc_pred: 0.9665 - val_loss: 242.4171 - val_acc_pred: 0.9619
# Epoch 88/500
# HBox(children=(IntProgress(value=0, description='Epoch 87', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 218.0208 - acc_pred: 0.9664 - val_loss: 242.0342 - val_acc_pred: 0.9620
# Epoch 89/500
# HBox(children=(IntProgress(value=0, description='Epoch 88', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 57s 2ms/step - loss: 217.8696 - acc_pred: 0.9665 - val_loss: 242.4025 - val_acc_pred: 0.9619
# Epoch 90/500
# HBox(children=(IntProgress(value=0, description='Epoch 89', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 218.1629 - acc_pred: 0.9664 - val_loss: 242.5416 - val_acc_pred: 0.9619
# Epoch 91/500
# HBox(children=(IntProgress(value=0, description='Epoch 90', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 217.8738 - acc_pred: 0.9665 - val_loss: 242.4773 - val_acc_pred: 0.9618
# Epoch 92/500
# HBox(children=(IntProgress(value=0, description='Epoch 91', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 217.7466 - acc_pred: 0.9665 - val_loss: 242.4312 - val_acc_pred: 0.9618
# Epoch 93/500
# HBox(children=(IntProgress(value=0, description='Epoch 92', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 218.0879 - acc_pred: 0.9664 - val_loss: 242.6442 - val_acc_pred: 0.9618
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-06.
# Epoch 94/500
# HBox(children=(IntProgress(value=0, description='Epoch 93', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 56s 2ms/step - loss: 217.8654 - acc_pred: 0.9665 - val_loss: 241.9154 - val_acc_pred: 0.9620
# Epoch 95/500
# HBox(children=(IntProgress(value=0, description='Epoch 94', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 58s 2ms/step - loss: 217.9102 - acc_pred: 0.9665 - val_loss: 242.3620 - val_acc_pred: 0.9619
# Epoch 96/500
# HBox(children=(IntProgress(value=0, description='Epoch 95', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 217.9636 - acc_pred: 0.9665 - val_loss: 242.1233 - val_acc_pred: 0.9619
# Epoch 97/500
# HBox(children=(IntProgress(value=0, description='Epoch 96', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.7974 - acc_pred: 0.9665 - val_loss: 242.4356 - val_acc_pred: 0.9619
# Epoch 98/500
# HBox(children=(IntProgress(value=0, description='Epoch 97', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.7506 - acc_pred: 0.9665 - val_loss: 242.8538 - val_acc_pred: 0.9618
# Epoch 99/500
# HBox(children=(IntProgress(value=0, description='Epoch 98', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.8797 - acc_pred: 0.9665 - val_loss: 242.2303 - val_acc_pred: 0.9619
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 1.6000001323845936e-06.
# Epoch 100/500
# HBox(children=(IntProgress(value=0, description='Epoch 99', max=23997, style=ProgressStyle(description_width='…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.6540 - acc_pred: 0.9665 - val_loss: 242.3518 - val_acc_pred: 0.9619
# Epoch 101/500
# HBox(children=(IntProgress(value=0, description='Epoch 100', max=23997, style=ProgressStyle(description_width=…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.7595 - acc_pred: 0.9665 - val_loss: 242.5386 - val_acc_pred: 0.9619
# Epoch 102/500
# HBox(children=(IntProgress(value=0, description='Epoch 101', max=23997, style=ProgressStyle(description_width=…
# 23997/23997 [==============================] - 55s 2ms/step - loss: 217.8768 - acc_pred: 0.9665 - val_loss: 242.3804 - val_acc_pred: 0.9619
# Epoch 103/500
# HBox(children=(IntProgress(value=0, description='Epoch 102', max=23997, style=ProgressStyle(description_width=…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.8564 - acc_pred: 0.9665 - val_loss: 242.5397 - val_acc_pred: 0.9619
# Epoch 104/500
# HBox(children=(IntProgress(value=0, description='Epoch 103', max=23997, style=ProgressStyle(description_width=…
# 23997/23997 [==============================] - 54s 2ms/step - loss: 217.8806 - acc_pred: 0.9664 - val_loss: 242.5585 - val_acc_pred: 0.9619
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-07.

# %%
PlotHistory(model.history.history,listKeys=['val_loss','loss'],axis_=[0,85,100,2000])
# Out:
# val_loss   :  [242.35179439290366, 242.53857971191405, 242.380364461263, 242.53969958496094]
# loss   :  [217.65402426808885, 217.75952592142255, 217.87678048137465, 217.856391515365]

# %%
PlotHistory(model.history.history,listKeys=['lr'])
# Out:
# lr   :  [1.2800001e-06, 1.2800001e-06, 1.2800001e-06, 1.2800001e-06]

# %%
PlotHistory(model.history.history,listKeys=['val_acc_pred','acc_pred'])
# Out:
# val_acc_pred   :  [0.96189728307724, 0.9618793439865112, 0.9618838655153911, 0.9619269145329793]
# acc_pred   :  [0.9665250750975385, 0.966496798673431, 0.9664902762482056, 0.9664654169533905]

# %%
x_rec=model.model.predict(x_test)
PlotDataAE(x_test[:,:,:,1],np.argmax(x_rec[:,:,:,:],axis=-1),digit_size=45)

# %%
x_gen=model.generate(binary=True)
PlotDataAE([],x_gen[:,:,:],digit_size=45,Only_Result=False)
