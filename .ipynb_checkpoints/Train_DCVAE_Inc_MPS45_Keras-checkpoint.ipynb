# %%
from Model.DCVAE import DCVAE_Inc
from Model.Utils import PlotHistory, PlotDataAE, Save_Model
from Model.Utils import load_from_tfrecords, convert_to_tfrecords, load_numpy
from keras.optimizers import RMSprop,Adam
import numpy as np
import tensorflow as tf
import os
# %matplotlib notebook
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Load DataSet

# %%
load_tfrecords = True 
create_tfrecords = False

path_tfr = 'DataSet/MPS45'
path_npy = '/share/GeoFacies/DataSet/MPS45/MPS45.npy'
batch_size = 32

# %%
if load_tfrecords:
    if create_tfrecords: 
        x_train, x_test = load_numpy(path_npy,random_state=0,split_data=0.30)
        convert_to_tfrecords(path_tfr, x_train, x_test)
        gen_train, gen_test = load_from_tfrecords(path_tfr, batch_size)
    else:
        try:
            gen_train, gen_test = load_from_tfrecords(path_tfr, batch_size)
        except:
            print("Data not found. Change 'create_tfrecords' to True")
else:
    x_train, x_test = load_numpy(path_npy,random_state=0,split_data=0.30)

# %% [markdown]
# # Create Convolutional Variational Autoencoder

# %%
path_weights = os.path.join(path_tfr, 'w45_Inc.hdf5')

model = DCVAE_Inc(input_shape=(45, 45, 2), kernel_init=32, latent_dim=500, drop = 0,
                  opt=RMSprop(lr=0.001),scheduler=True, filepath = path_weights)

# %% [markdown]
# # Training Network

# %%
num_epochs = 500

if load_tfrecords:
    x_train = gen_train.mps_generator()
    x_val = gen_test.mps_generator()
    model.fit_generator(x_train,
                        num_epochs=num_epochs, verbose=1, 
                        steps_per_epoch = len(gen_train),
                        val_set = x_val,
                        validation_steps = len(gen_test))
else:
    model.fit(x_train, num_epochs=num_epochs, batch_size = batch_size, x_v=x_test,verbose=1)
# Out:
# Setting up model...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 45, 45, 2)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 45, 45, 32)   96          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 45, 45, 16)   528         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 45, 45, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 45, 45, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 45, 45, 32)   544         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 45, 45, 32)   4640        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 45, 45, 32)   12832       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 45, 45, 32)   25120       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 45, 45, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 45, 45, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 45, 45, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 45, 45, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 45, 45, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 45, 45, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 45, 45, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 45, 45, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 45, 45, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 45, 45, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 45, 45, 32)   0           activation_2[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
#                                                                  activation_5[0][0]
#                                                                  max_pooling2d_1[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 22, 22, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 22, 22, 64)   2112        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 22, 22, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 22, 22, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 22, 22, 32)   2080        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 22, 22, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 22, 22, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 22, 22, 64)   2112        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 22, 22, 64)   18496       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 22, 22, 64)   51264       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 22, 22, 64)   100416      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 22, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 22, 22, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 22, 22, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 22, 22, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 22, 22, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 22, 22, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 22, 22, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 22, 22, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 22, 22, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 22, 22, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 22, 22, 64)   0           activation_8[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  max_pooling2d_3[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 11, 11, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 11, 11, 128)  8320        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 11, 11, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 11, 11, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 11, 11, 64)   8256        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 11, 11, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 11, 11, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 11, 11, 128)  8320        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 11, 11, 128)  73856       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 11, 11, 128)  204928      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 11, 11, 128)  401536      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 11, 11, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 11, 11, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 11, 11, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 11, 11, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 11, 11, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 11, 11, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 11, 11, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 11, 11, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 11, 11, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 11, 11, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 11, 11, 128)  0           activation_14[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_16[0][0]
#                                                                  activation_17[0][0]
#                                                                  max_pooling2d_5[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 2, 2, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 256)    33024       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 2, 2, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2, 2, 256)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 128)    32896       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 2, 2, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2, 2, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 256)    33024       activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 256)    295168      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 256)    819456      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 256)    1605888     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 2, 2, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 2, 2, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 2, 2, 256)    1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 2, 2, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 2, 2, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2, 2, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2, 2, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 2, 2, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 2, 2, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 2, 2, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2, 2, 256)    0           activation_20[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_23[0][0]
#                                                                  max_pooling2d_7[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 256)       0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 256)          0           lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 500)          128500      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 500)          128500      dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 500)          0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          128256      lambda_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 256)       0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 256)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 3, 3, 256)    0           lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 3, 3, 128)    32896       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 3, 3, 128)    512         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 3, 3, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 3, 3, 256)    33024       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 3, 3, 256)    295168      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 3, 3, 256)    819456      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 3, 3, 256)    1605888     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 3, 3, 256)    1024        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 3, 3, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 3, 3, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 3, 3, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 256)    0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 3, 3, 256)    0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 3, 3, 256)    0           activation_25[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_28[0][0]
#                                                                  max_pooling2d_9[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 12, 12, 128)  524416      add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 12, 12, 64)   8256        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 64)   256         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 12, 12, 128)  8320        activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 12, 12, 128)  73856       activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 12, 12, 128)  204928      activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 12, 12, 128)  401536      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 128)  512         conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 12, 12, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 12, 12, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 12, 128)  0           activation_31[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_34[0][0]
#                                                                  max_pooling2d_11[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 24, 24, 64)   32832       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 24, 24, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 24, 24, 32)   2080        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 24, 24, 32)   128         conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 24, 24, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 24, 24, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 24, 24, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 24, 24, 64)   51264       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 24, 24, 64)   100416      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 24, 24, 64)   256         conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 24, 24, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 24, 24, 64)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 24, 24, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 24, 24, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 24, 24, 64)   0           activation_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 24, 24, 64)   0           activation_35[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 24, 24, 64)   0           activation_37[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  max_pooling2d_13[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 48, 48, 32)   8224        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 48, 48, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 48, 48, 16)   528         activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 48, 48, 16)   64          conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 48, 48, 16)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 48, 48, 32)   544         activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 48, 48, 32)   4640        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 48, 48, 32)   12832       activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 48, 48, 32)   25120       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 48, 48, 32)   128         conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 48, 48, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 48, 48, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 48, 48, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 48, 48, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 48, 48, 32)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 48, 48, 32)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 48, 48, 32)   0           activation_43[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_46[0][0]
#                                                                  max_pooling2d_15[0][0]
#                                                                  max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_1 (Bilinear (None, 45, 45, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 45, 45, 2)    66          bilinear_upsampling_1[0][0]
# ==================================================================================================
# Total params: 8,417,034
# Trainable params: 8,407,050
# Non-trainable params: 9,984
# __________________________________________________________________________________________________
# Completed model setup.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# HBox(children=(IntProgress(value=0, description='Training', max=500, style=ProgressStyle(description_width='in…
# Epoch 1/500
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 66s 100ms/step - loss: 1052.1886 - acc_pred: 0.8095 - val_loss: 1064.4657 - val_acc_pred: 0.8125
# Epoch 2/500
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 646.7518 - acc_pred: 0.8805 - val_loss: 684.7760 - val_acc_pred: 0.8746
# Epoch 3/500
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 560.2322 - acc_pred: 0.8977 - val_loss: 648.7970 - val_acc_pred: 0.8832
# Epoch 4/500
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 514.4923 - acc_pred: 0.9065 - val_loss: 537.3151 - val_acc_pred: 0.9029
# Epoch 5/500
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 475.2345 - acc_pred: 0.9143 - val_loss: 530.6227 - val_acc_pred: 0.9007
# Epoch 6/500
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 53s 81ms/step - loss: 442.2480 - acc_pred: 0.9205 - val_loss: 442.9352 - val_acc_pred: 0.9199
# Epoch 7/500
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 412.5811 - acc_pred: 0.9261 - val_loss: 418.4936 - val_acc_pred: 0.9241
# Epoch 8/500
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 389.2624 - acc_pred: 0.9304 - val_loss: 394.1410 - val_acc_pred: 0.9294
# Epoch 9/500
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 371.0227 - acc_pred: 0.9338 - val_loss: 391.9810 - val_acc_pred: 0.9318
# Epoch 10/500
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=656, style=ProgressStyle(description_width='ini…
# 656/656 [==============================] - 54s 82ms/step - loss: 357.7640 - acc_pred: 0.9364 - val_loss: 357.5765 - val_acc_pred: 0.9362
# Epoch 11/500
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 346.4413 - acc_pred: 0.9386 - val_loss: 341.5618 - val_acc_pred: 0.9385
# Epoch 12/500
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 54s 82ms/step - loss: 336.0585 - acc_pred: 0.9406 - val_loss: 344.0635 - val_acc_pred: 0.9395
# Epoch 13/500
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 327.3245 - acc_pred: 0.9424 - val_loss: 348.4396 - val_acc_pred: 0.9377
# Epoch 14/500
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 319.3073 - acc_pred: 0.9440 - val_loss: 328.8151 - val_acc_pred: 0.9422
# Epoch 15/500
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 312.6533 - acc_pred: 0.9453 - val_loss: 332.3693 - val_acc_pred: 0.9408
# Epoch 16/500
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 306.8721 - acc_pred: 0.9465 - val_loss: 319.2750 - val_acc_pred: 0.9432
# Epoch 17/500
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 302.0582 - acc_pred: 0.9475 - val_loss: 320.0439 - val_acc_pred: 0.9431
# Epoch 18/500
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 54s 82ms/step - loss: 297.5466 - acc_pred: 0.9484 - val_loss: 324.9306 - val_acc_pred: 0.9429
# Epoch 19/500
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 292.7918 - acc_pred: 0.9495 - val_loss: 310.0583 - val_acc_pred: 0.9452
# Epoch 20/500
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 289.8091 - acc_pred: 0.9501 - val_loss: 292.8980 - val_acc_pred: 0.9494
# Epoch 21/500
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 285.7266 - acc_pred: 0.9510 - val_loss: 308.9161 - val_acc_pred: 0.9464
# Epoch 22/500
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 282.7081 - acc_pred: 0.9517 - val_loss: 288.4548 - val_acc_pred: 0.9499
# Epoch 23/500
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 279.9748 - acc_pred: 0.9523 - val_loss: 291.1799 - val_acc_pred: 0.9500
# Epoch 24/500
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 277.2554 - acc_pred: 0.9529 - val_loss: 298.9296 - val_acc_pred: 0.9489
# Epoch 25/500
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 274.4517 - acc_pred: 0.9535 - val_loss: 297.1014 - val_acc_pred: 0.9483
# Epoch 26/500
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 272.5441 - acc_pred: 0.9539 - val_loss: 282.5981 - val_acc_pred: 0.9512
# Epoch 27/500
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 270.7592 - acc_pred: 0.9543 - val_loss: 288.5152 - val_acc_pred: 0.9503
# Epoch 28/500
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 268.5390 - acc_pred: 0.9548 - val_loss: 277.0944 - val_acc_pred: 0.9529
# Epoch 29/500
# HBox(children=(IntProgress(value=0, description='Epoch 28', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 267.2307 - acc_pred: 0.9551 - val_loss: 281.6495 - val_acc_pred: 0.9518
# Epoch 30/500
# HBox(children=(IntProgress(value=0, description='Epoch 29', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 52s 80ms/step - loss: 265.2061 - acc_pred: 0.9555 - val_loss: 287.7251 - val_acc_pred: 0.9509
# Epoch 31/500
# HBox(children=(IntProgress(value=0, description='Epoch 30', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 264.1719 - acc_pred: 0.9558 - val_loss: 292.9821 - val_acc_pred: 0.9497
# Epoch 32/500
# HBox(children=(IntProgress(value=0, description='Epoch 31', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 262.3023 - acc_pred: 0.9562 - val_loss: 286.3262 - val_acc_pred: 0.9514
# Epoch 33/500
# HBox(children=(IntProgress(value=0, description='Epoch 32', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 261.0037 - acc_pred: 0.9565 - val_loss: 296.1311 - val_acc_pred: 0.9488
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 34/500
# HBox(children=(IntProgress(value=0, description='Epoch 33', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 245.9934 - acc_pred: 0.9598 - val_loss: 261.8310 - val_acc_pred: 0.9564
# Epoch 35/500
# HBox(children=(IntProgress(value=0, description='Epoch 34', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 243.0741 - acc_pred: 0.9605 - val_loss: 261.2853 - val_acc_pred: 0.9565
# Epoch 36/500
# HBox(children=(IntProgress(value=0, description='Epoch 35', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 241.2600 - acc_pred: 0.9608 - val_loss: 260.0366 - val_acc_pred: 0.9568
# Epoch 37/500
# HBox(children=(IntProgress(value=0, description='Epoch 36', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 240.4553 - acc_pred: 0.9611 - val_loss: 261.7911 - val_acc_pred: 0.9568
# Epoch 38/500
# HBox(children=(IntProgress(value=0, description='Epoch 37', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 239.1090 - acc_pred: 0.9613 - val_loss: 273.3960 - val_acc_pred: 0.9539
# Epoch 39/500
# HBox(children=(IntProgress(value=0, description='Epoch 38', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 238.2284 - acc_pred: 0.9616 - val_loss: 259.3053 - val_acc_pred: 0.9575
# Epoch 40/500
# HBox(children=(IntProgress(value=0, description='Epoch 39', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 237.3494 - acc_pred: 0.9617 - val_loss: 262.8489 - val_acc_pred: 0.9565
# Epoch 41/500
# HBox(children=(IntProgress(value=0, description='Epoch 40', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 236.5820 - acc_pred: 0.9619 - val_loss: 261.9982 - val_acc_pred: 0.9568
# Epoch 42/500
# HBox(children=(IntProgress(value=0, description='Epoch 41', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 52s 79ms/step - loss: 235.8141 - acc_pred: 0.9621 - val_loss: 258.7071 - val_acc_pred: 0.9574
# Epoch 43/500
# HBox(children=(IntProgress(value=0, description='Epoch 42', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 234.7949 - acc_pred: 0.9624 - val_loss: 259.8473 - val_acc_pred: 0.9573
# Epoch 44/500
# HBox(children=(IntProgress(value=0, description='Epoch 43', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 233.9671 - acc_pred: 0.9625 - val_loss: 262.5945 - val_acc_pred: 0.9568
# Epoch 45/500
# HBox(children=(IntProgress(value=0, description='Epoch 44', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 232.9275 - acc_pred: 0.9627 - val_loss: 259.9737 - val_acc_pred: 0.9574
# Epoch 46/500
# HBox(children=(IntProgress(value=0, description='Epoch 45', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 232.5146 - acc_pred: 0.9628 - val_loss: 256.6277 - val_acc_pred: 0.9580
# Epoch 47/500
# HBox(children=(IntProgress(value=0, description='Epoch 46', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 231.5797 - acc_pred: 0.9630 - val_loss: 261.0199 - val_acc_pred: 0.9574
# Epoch 48/500
# HBox(children=(IntProgress(value=0, description='Epoch 47', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 230.6181 - acc_pred: 0.9633 - val_loss: 258.1924 - val_acc_pred: 0.9578
# Epoch 49/500
# HBox(children=(IntProgress(value=0, description='Epoch 48', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 230.1109 - acc_pred: 0.9634 - val_loss: 260.0402 - val_acc_pred: 0.9574
# Epoch 50/500
# HBox(children=(IntProgress(value=0, description='Epoch 49', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 229.4071 - acc_pred: 0.9635 - val_loss: 259.5340 - val_acc_pred: 0.9575
# Epoch 51/500
# HBox(children=(IntProgress(value=0, description='Epoch 50', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 228.6616 - acc_pred: 0.9637 - val_loss: 259.4374 - val_acc_pred: 0.9575
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 52/500
# HBox(children=(IntProgress(value=0, description='Epoch 51', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 52s 80ms/step - loss: 222.1211 - acc_pred: 0.9652 - val_loss: 253.6577 - val_acc_pred: 0.9592
# Epoch 53/500
# HBox(children=(IntProgress(value=0, description='Epoch 52', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 52s 80ms/step - loss: 220.8720 - acc_pred: 0.9654 - val_loss: 253.0903 - val_acc_pred: 0.9592
# Epoch 54/500
# HBox(children=(IntProgress(value=0, description='Epoch 53', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 219.8704 - acc_pred: 0.9656 - val_loss: 254.8055 - val_acc_pred: 0.9589
# Epoch 55/500
# HBox(children=(IntProgress(value=0, description='Epoch 54', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 219.3840 - acc_pred: 0.9658 - val_loss: 254.7836 - val_acc_pred: 0.9591
# Epoch 56/500
# HBox(children=(IntProgress(value=0, description='Epoch 55', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 218.9640 - acc_pred: 0.9659 - val_loss: 254.1590 - val_acc_pred: 0.9593
# Epoch 57/500
# HBox(children=(IntProgress(value=0, description='Epoch 56', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 218.3984 - acc_pred: 0.9660 - val_loss: 254.8861 - val_acc_pred: 0.9591
# Epoch 58/500
# HBox(children=(IntProgress(value=0, description='Epoch 57', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 217.8112 - acc_pred: 0.9662 - val_loss: 257.0394 - val_acc_pred: 0.9587
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 59/500
# HBox(children=(IntProgress(value=0, description='Epoch 58', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 215.0368 - acc_pred: 0.9667 - val_loss: 252.2263 - val_acc_pred: 0.9599
# Epoch 60/500
# HBox(children=(IntProgress(value=0, description='Epoch 59', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 214.2617 - acc_pred: 0.9670 - val_loss: 252.0288 - val_acc_pred: 0.9600
# Epoch 61/500
# HBox(children=(IntProgress(value=0, description='Epoch 60', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 213.7294 - acc_pred: 0.9671 - val_loss: 252.7445 - val_acc_pred: 0.9599
# Epoch 62/500
# HBox(children=(IntProgress(value=0, description='Epoch 61', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 213.4853 - acc_pred: 0.9671 - val_loss: 253.2293 - val_acc_pred: 0.9598
# Epoch 63/500
# HBox(children=(IntProgress(value=0, description='Epoch 62', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 213.3411 - acc_pred: 0.9672 - val_loss: 253.4802 - val_acc_pred: 0.9597
# Epoch 64/500
# HBox(children=(IntProgress(value=0, description='Epoch 63', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 80ms/step - loss: 213.0576 - acc_pred: 0.9673 - val_loss: 253.1994 - val_acc_pred: 0.9598
# Epoch 65/500
# HBox(children=(IntProgress(value=0, description='Epoch 64', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 52s 80ms/step - loss: 212.4458 - acc_pred: 0.9674 - val_loss: 254.2205 - val_acc_pred: 0.9598
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 66/500
# HBox(children=(IntProgress(value=0, description='Epoch 65', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 211.2026 - acc_pred: 0.9677 - val_loss: 252.1697 - val_acc_pred: 0.9601
# Epoch 67/500
# HBox(children=(IntProgress(value=0, description='Epoch 66', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 211.0220 - acc_pred: 0.9677 - val_loss: 252.6359 - val_acc_pred: 0.9601
# Epoch 68/500
# HBox(children=(IntProgress(value=0, description='Epoch 67', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 210.6577 - acc_pred: 0.9678 - val_loss: 252.7562 - val_acc_pred: 0.9601
# Epoch 69/500
# HBox(children=(IntProgress(value=0, description='Epoch 68', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 52s 80ms/step - loss: 210.4398 - acc_pred: 0.9679 - val_loss: 252.7096 - val_acc_pred: 0.9602
# Epoch 70/500
# HBox(children=(IntProgress(value=0, description='Epoch 69', max=656, style=ProgressStyle(description_width='in…
# 656/656 [==============================] - 53s 81ms/step - loss: 210.2450 - acc_pred: 0.9679 - val_loss: 253.0215 - val_acc_pred: 0.9601
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.

# %% [markdown]
# # Ploting Train History

# %%
PlotHistory(model.history.history,listKeys=['val_loss','loss'])
# Out:
# val_loss   :  [252.1697049938487, 252.63589026834617, 252.75619604579072, 252.70960417506532]
# loss   :  [211.2025574940007, 211.02196914393727, 210.65770465571705, 210.4397807470182]

# %%
PlotHistory(model.history.history,listKeys=['val_acc_pred','acc_pred'])
# Out:
# val_acc_pred   :  [0.960149983282191, 0.9601214260817422, 0.9601002269792387, 0.9601551434323456]
# acc_pred   :  [0.9676642964889364, 0.9677371986937232, 0.9677763419543824, 0.967854514263752]

# %%
PlotHistory(model.history.history,listKeys=['lr'])
# Out:
# lr   :  [6.25e-05, 6.25e-05, 6.25e-05, 6.25e-05]

# %% [markdown]
# # Evaluate Model with Test dataset

# %%
if load_tfrecords:
    x_test = gen_test.get_numpy_batch()

x_rec = model.model.predict(x_test)
PlotDataAE(x_test[:,:,:,1], np.argmax(x_rec[:,:,:,:],axis=-1),digit_size=(45,45))

# %% [markdown]
# # Generate random sampling

# %%
x_gen=model.generate(binary=True)
PlotDataAE([],x_gen[:,:,:],digit_size=(45,45),Only_Result=False)
