# %%
from Model.DCVAE import DCVAE_Inc
from Model.Utils import LoadMPS100,PlotHistory,PlotDataAE
from keras.utils import to_categorical
from keras.optimizers import RMSprop,Adam
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
x_train1,x_test1=LoadMPS100(dirBase='DataSet/MPS-100.mat',AllTrain=True);
x_train=to_categorical(x_train1,2)
x_test=to_categorical(x_test1,2)

# %%
model = DCVAE_Inc(input_shape=(100,100,2),kernel_init=64,latent_dim=500,opt=RMSprop(),scheduler=True)

# %%
model.fit(x_train, num_epochs=500,batch_size=64,val_split=0.2,verbose=1)
# Out:
# Setting up model...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100, 100, 2)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 32) 96          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 100, 16) 528         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100, 100, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 100, 32) 544         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 100, 100, 32) 4640        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 100, 100, 32) 12832       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 100, 100, 32) 25120       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 100, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 100, 100, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 100, 100, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100, 100, 32) 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 100, 100, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100, 100, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100, 100, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100, 100, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 100, 100, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 100, 100, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 100, 32) 0           activation_2[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
#                                                                  activation_5[0][0]
#                                                                  max_pooling2d_1[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 50, 50, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 64)   2112        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   2080        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 64)   2112        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 64)   18496       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 64)   51264       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 50, 50, 64)   100416      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 50, 50, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 50, 50, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 50, 50, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 50, 50, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 50, 50, 64)   0           activation_8[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  max_pooling2d_3[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 128)  8320        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 64)   8256        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 128)  8320        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 128)  73856       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 128)  204928      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 128)  401536      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 25, 25, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 25, 25, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 25, 25, 128)  0           activation_14[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_16[0][0]
#                                                                  activation_17[0][0]
#                                                                  max_pooling2d_5[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 6, 6, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 6, 6, 256)    33024       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 6, 6, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 6, 6, 256)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 6, 6, 128)    32896       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 6, 6, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 6, 6, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 6, 6, 256)    33024       activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 6, 6, 256)    295168      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 256)    819456      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 6, 6, 256)    1605888     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 6, 6, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 256)    1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 6, 6, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 6, 6, 256)    0           activation_20[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_23[0][0]
#                                                                  max_pooling2d_7[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 256)       0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 256)          0           lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 500)          128500      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 500)          128500      dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 500)          0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          128256      lambda_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 256)       0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 256)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 7, 7, 256)    0           lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 7, 7, 128)    32896       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 128)    512         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 7, 7, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 7, 7, 256)    33024       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 7, 7, 256)    295168      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 7, 7, 256)    819456      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 7, 7, 256)    1605888     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, 7, 256)    1024        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, 7, 256)    1024        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 7, 7, 256)    1024        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 7, 7, 256)    1024        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 7, 7, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 7, 7, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 7, 7, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 7, 7, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 256)    0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 256)    0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 256)    0           activation_25[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_28[0][0]
#                                                                  max_pooling2d_9[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 28, 28, 128)  524416      add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 28, 28, 64)   8256        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 64)   256         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 28, 28, 128)  8320        activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 28, 28, 128)  73856       activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 28, 28, 128)  204928      activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 28, 28, 128)  401536      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 28, 28, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 28, 28, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 128)  0           activation_31[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_34[0][0]
#                                                                  max_pooling2d_11[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 56, 56, 64)   32832       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 56, 56, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 56, 56, 32)   2080        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 56, 56, 32)   128         conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 56, 56, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 56, 56, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 56, 56, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 56, 56, 64)   51264       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 56, 56, 64)   100416      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 56, 56, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 56, 56, 64)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 56, 56, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 56, 56, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 56, 56, 64)   0           activation_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 56, 56, 64)   0           activation_35[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 56, 56, 64)   0           activation_37[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  max_pooling2d_13[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 112, 112, 32) 8224        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 112, 112, 32) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 112, 112, 16) 528         activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 112, 112, 16) 64          conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 112, 112, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 112, 112, 32) 544         activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 112, 112, 32) 4640        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 112, 112, 32) 12832       activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 112, 112, 32) 25120       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 112, 112, 32) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 112, 112, 32) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 112, 112, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 112, 112, 32) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 112, 112, 32) 0           activation_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 112, 112, 32) 0           activation_41[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 112, 112, 32) 0           activation_43[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_46[0][0]
#                                                                  max_pooling2d_15[0][0]
#                                                                  max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_1 (Bilinear (None, 100, 100, 32) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 100, 100, 2)  66          bilinear_upsampling_1[0][0]
# ==================================================================================================
# Total params: 8,417,034
# Trainable params: 8,407,050
# Non-trainable params: 9,984
# __________________________________________________________________________________________________
# Completed model setup.
# Train on 32000 samples, validate on 8000 samples
# HBox(children=(IntProgress(value=0, description='Training', max=500, style=ProgressStyle(description_width='in…
# Epoch 1/500
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 293s 9ms/step - loss: 6958.5372 - acc_pred: 0.6799 - val_loss: 6314.0854 - val_acc_pred: 0.6833
# Epoch 2/500
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 282s 9ms/step - loss: 5970.2386 - acc_pred: 0.6933 - val_loss: 6377.7540 - val_acc_pred: 0.6622
# Epoch 3/500
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 5276.4738 - acc_pred: 0.7335 - val_loss: 5612.6332 - val_acc_pred: 0.7126
# Epoch 4/500
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 4748.5888 - acc_pred: 0.7696 - val_loss: 4579.7130 - val_acc_pred: 0.7826
# Epoch 5/500
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 4382.2844 - acc_pred: 0.7939 - val_loss: 4580.6706 - val_acc_pred: 0.7848
# Epoch 6/500
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 4099.1186 - acc_pred: 0.8119 - val_loss: 4064.7650 - val_acc_pred: 0.8141
# Epoch 7/500
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3891.5897 - acc_pred: 0.8245 - val_loss: 3820.5137 - val_acc_pred: 0.8296
# Epoch 8/500
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3721.3452 - acc_pred: 0.8345 - val_loss: 3681.9386 - val_acc_pred: 0.8387
# Epoch 9/500
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 282s 9ms/step - loss: 3579.5952 - acc_pred: 0.8425 - val_loss: 3424.6084 - val_acc_pred: 0.8517
# Epoch 10/500
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=32000, style=ProgressStyle(description_width='i…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3461.1562 - acc_pred: 0.8490 - val_loss: 3428.1016 - val_acc_pred: 0.8498
# Epoch 11/500
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 3372.3152 - acc_pred: 0.8537 - val_loss: 3344.7956 - val_acc_pred: 0.8545
# Epoch 12/500
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 3290.7600 - acc_pred: 0.8580 - val_loss: 3191.1724 - val_acc_pred: 0.8637
# Epoch 13/500
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3221.6315 - acc_pred: 0.8616 - val_loss: 4840.9048 - val_acc_pred: 0.7760
# Epoch 14/500
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3158.5043 - acc_pred: 0.8647 - val_loss: 2976.1431 - val_acc_pred: 0.8738
# Epoch 15/500
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3105.8217 - acc_pred: 0.8675 - val_loss: 2821.0219 - val_acc_pred: 0.8816
# Epoch 16/500
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 3055.7239 - acc_pred: 0.8700 - val_loss: 2834.0541 - val_acc_pred: 0.8801
# Epoch 17/500
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 3013.2260 - acc_pred: 0.8721 - val_loss: 2786.5676 - val_acc_pred: 0.8860
# Epoch 18/500
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2976.7973 - acc_pred: 0.8739 - val_loss: 2730.8077 - val_acc_pred: 0.8853
# Epoch 19/500
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2945.3182 - acc_pred: 0.8753 - val_loss: 2770.1300 - val_acc_pred: 0.8838
# Epoch 20/500
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2874.8224 - acc_pred: 0.8788 - val_loss: 2598.0228 - val_acc_pred: 0.8923
# Epoch 21/500
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2849.8137 - acc_pred: 0.8800 - val_loss: 3337.1733 - val_acc_pred: 0.8558
# Epoch 22/500
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2824.6844 - acc_pred: 0.8812 - val_loss: 2534.9328 - val_acc_pred: 0.8961
# Epoch 23/500
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2804.2136 - acc_pred: 0.8822 - val_loss: 2511.1157 - val_acc_pred: 0.8987
# Epoch 24/500
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2782.2086 - acc_pred: 0.8832 - val_loss: 2480.2184 - val_acc_pred: 0.8990
# Epoch 25/500
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2762.6325 - acc_pred: 0.8841 - val_loss: 2484.9868 - val_acc_pred: 0.8980
# Epoch 26/500
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2746.1821 - acc_pred: 0.8849 - val_loss: 2481.6842 - val_acc_pred: 0.8985
# Epoch 27/500
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2729.4929 - acc_pred: 0.8857 - val_loss: 2555.8407 - val_acc_pred: 0.8943
# Epoch 28/500
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=32000, style=ProgressStyle(description_width='…
# ...
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2313.7163 - acc_pred: 0.9050 - val_loss: 2033.5079 - val_acc_pred: 0.9190
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.0001280000142287463.
# Epoch 79/500
# HBox(children=(IntProgress(value=0, description='Epoch 78', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2299.1791 - acc_pred: 0.9056 - val_loss: 2003.3176 - val_acc_pred: 0.9205
# Epoch 80/500
# HBox(children=(IntProgress(value=0, description='Epoch 79', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2292.5032 - acc_pred: 0.9059 - val_loss: 1993.7823 - val_acc_pred: 0.9208
# Epoch 81/500
# HBox(children=(IntProgress(value=0, description='Epoch 80', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2288.3510 - acc_pred: 0.9061 - val_loss: 2008.7310 - val_acc_pred: 0.9202
# Epoch 82/500
# HBox(children=(IntProgress(value=0, description='Epoch 81', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2284.8392 - acc_pred: 0.9063 - val_loss: 1997.4620 - val_acc_pred: 0.9207
# Epoch 83/500
# HBox(children=(IntProgress(value=0, description='Epoch 82', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2283.7848 - acc_pred: 0.9064 - val_loss: 1993.2296 - val_acc_pred: 0.9208
# Epoch 84/500
# HBox(children=(IntProgress(value=0, description='Epoch 83', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2280.5468 - acc_pred: 0.9065 - val_loss: 1998.1671 - val_acc_pred: 0.9207
# Epoch 85/500
# HBox(children=(IntProgress(value=0, description='Epoch 84', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2280.6173 - acc_pred: 0.9065 - val_loss: 1993.2234 - val_acc_pred: 0.9210
# Epoch 86/500
# HBox(children=(IntProgress(value=0, description='Epoch 85', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2278.7760 - acc_pred: 0.9066 - val_loss: 1985.2972 - val_acc_pred: 0.9213
# Epoch 87/500
# HBox(children=(IntProgress(value=0, description='Epoch 86', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2278.4865 - acc_pred: 0.9066 - val_loss: 1996.4409 - val_acc_pred: 0.9208
# Epoch 88/500
# HBox(children=(IntProgress(value=0, description='Epoch 87', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2278.0319 - acc_pred: 0.9066 - val_loss: 1986.8891 - val_acc_pred: 0.9212
# Epoch 89/500
# HBox(children=(IntProgress(value=0, description='Epoch 88', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2277.7052 - acc_pred: 0.9066 - val_loss: 1986.4536 - val_acc_pred: 0.9213
# Epoch 90/500
# HBox(children=(IntProgress(value=0, description='Epoch 89', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2274.1272 - acc_pred: 0.9068 - val_loss: 1992.6912 - val_acc_pred: 0.9206
# Epoch 91/500
# HBox(children=(IntProgress(value=0, description='Epoch 90', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2275.5841 - acc_pred: 0.9067 - val_loss: 1986.4523 - val_acc_pred: 0.9212
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 5.1200004236306995e-05.
# Epoch 92/500
# HBox(children=(IntProgress(value=0, description='Epoch 91', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2268.7151 - acc_pred: 0.9070 - val_loss: 1983.8736 - val_acc_pred: 0.9213
# Epoch 93/500
# HBox(children=(IntProgress(value=0, description='Epoch 92', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2267.8094 - acc_pred: 0.9071 - val_loss: 1983.8182 - val_acc_pred: 0.9213
# Epoch 94/500
# HBox(children=(IntProgress(value=0, description='Epoch 93', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2263.8454 - acc_pred: 0.9073 - val_loss: 1981.8468 - val_acc_pred: 0.9213
# Epoch 95/500
# HBox(children=(IntProgress(value=0, description='Epoch 94', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2264.6149 - acc_pred: 0.9072 - val_loss: 1977.5198 - val_acc_pred: 0.9214
# Epoch 96/500
# HBox(children=(IntProgress(value=0, description='Epoch 95', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2264.3884 - acc_pred: 0.9072 - val_loss: 1982.9606 - val_acc_pred: 0.9213
# Epoch 97/500
# HBox(children=(IntProgress(value=0, description='Epoch 96', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2262.6347 - acc_pred: 0.9073 - val_loss: 1977.8435 - val_acc_pred: 0.9216
# Epoch 98/500
# HBox(children=(IntProgress(value=0, description='Epoch 97', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2261.7201 - acc_pred: 0.9074 - val_loss: 1978.4979 - val_acc_pred: 0.9216
# Epoch 99/500
# HBox(children=(IntProgress(value=0, description='Epoch 98', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2261.9830 - acc_pred: 0.9074 - val_loss: 1975.1602 - val_acc_pred: 0.9215
# Epoch 100/500
# HBox(children=(IntProgress(value=0, description='Epoch 99', max=32000, style=ProgressStyle(description_width='…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2259.0392 - acc_pred: 0.9075 - val_loss: 1971.7086 - val_acc_pred: 0.9217
# Epoch 101/500
# HBox(children=(IntProgress(value=0, description='Epoch 100', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2260.3176 - acc_pred: 0.9075 - val_loss: 1972.2439 - val_acc_pred: 0.9217
# Epoch 102/500
# HBox(children=(IntProgress(value=0, description='Epoch 101', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2257.4259 - acc_pred: 0.9076 - val_loss: 1975.8066 - val_acc_pred: 0.9217
# Epoch 103/500
# HBox(children=(IntProgress(value=0, description='Epoch 102', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2258.2858 - acc_pred: 0.9075 - val_loss: 1980.9718 - val_acc_pred: 0.9214
# Epoch 104/500
# HBox(children=(IntProgress(value=0, description='Epoch 103', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2257.5003 - acc_pred: 0.9076 - val_loss: 1977.2360 - val_acc_pred: 0.9216
# Epoch 105/500
# HBox(children=(IntProgress(value=0, description='Epoch 104', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2256.1061 - acc_pred: 0.9076 - val_loss: 1975.0373 - val_acc_pred: 0.9216
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 2.0480001694522798e-05.
# Epoch 106/500
# HBox(children=(IntProgress(value=0, description='Epoch 105', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2252.7360 - acc_pred: 0.9078 - val_loss: 1971.1814 - val_acc_pred: 0.9217
# Epoch 107/500
# HBox(children=(IntProgress(value=0, description='Epoch 106', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2253.2647 - acc_pred: 0.9077 - val_loss: 1973.7278 - val_acc_pred: 0.9217
# Epoch 108/500
# HBox(children=(IntProgress(value=0, description='Epoch 107', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2253.0024 - acc_pred: 0.9078 - val_loss: 1971.9810 - val_acc_pred: 0.9218
# Epoch 109/500
# HBox(children=(IntProgress(value=0, description='Epoch 108', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2254.0180 - acc_pred: 0.9077 - val_loss: 1971.1623 - val_acc_pred: 0.9218
# Epoch 110/500
# HBox(children=(IntProgress(value=0, description='Epoch 109', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2252.3098 - acc_pred: 0.9078 - val_loss: 1969.1110 - val_acc_pred: 0.9219
# Epoch 111/500
# HBox(children=(IntProgress(value=0, description='Epoch 110', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2254.0051 - acc_pred: 0.9077 - val_loss: 1970.7723 - val_acc_pred: 0.9217
# Epoch 112/500
# HBox(children=(IntProgress(value=0, description='Epoch 111', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2253.0214 - acc_pred: 0.9078 - val_loss: 1972.6919 - val_acc_pred: 0.9217
# Epoch 113/500
# HBox(children=(IntProgress(value=0, description='Epoch 112', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2250.7062 - acc_pred: 0.9079 - val_loss: 1970.0527 - val_acc_pred: 0.9219
# Epoch 114/500
# HBox(children=(IntProgress(value=0, description='Epoch 113', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2251.5468 - acc_pred: 0.9078 - val_loss: 1971.1662 - val_acc_pred: 0.9218
# Epoch 115/500
# HBox(children=(IntProgress(value=0, description='Epoch 114', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2251.6164 - acc_pred: 0.9078 - val_loss: 1970.0424 - val_acc_pred: 0.9219
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# Epoch 116/500
# HBox(children=(IntProgress(value=0, description='Epoch 115', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2252.0867 - acc_pred: 0.9078 - val_loss: 1969.6405 - val_acc_pred: 0.9219
# Epoch 117/500
# HBox(children=(IntProgress(value=0, description='Epoch 116', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2249.0265 - acc_pred: 0.9080 - val_loss: 1969.4878 - val_acc_pred: 0.9219
# Epoch 118/500
# HBox(children=(IntProgress(value=0, description='Epoch 117', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2248.0069 - acc_pred: 0.9080 - val_loss: 1967.6462 - val_acc_pred: 0.9219
# Epoch 119/500
# HBox(children=(IntProgress(value=0, description='Epoch 118', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2249.3477 - acc_pred: 0.9079 - val_loss: 1968.7660 - val_acc_pred: 0.9219
# Epoch 120/500
# HBox(children=(IntProgress(value=0, description='Epoch 119', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2247.1637 - acc_pred: 0.9081 - val_loss: 1967.7365 - val_acc_pred: 0.9219
# Epoch 121/500
# HBox(children=(IntProgress(value=0, description='Epoch 120', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2250.1695 - acc_pred: 0.9079 - val_loss: 1970.2467 - val_acc_pred: 0.9219
# Epoch 122/500
# HBox(children=(IntProgress(value=0, description='Epoch 121', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2249.0588 - acc_pred: 0.9080 - val_loss: 1967.6195 - val_acc_pred: 0.9220
# Epoch 123/500
# HBox(children=(IntProgress(value=0, description='Epoch 122', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2249.5070 - acc_pred: 0.9079 - val_loss: 1968.4388 - val_acc_pred: 0.9220
# Epoch 124/500
# HBox(children=(IntProgress(value=0, description='Epoch 123', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2248.0912 - acc_pred: 0.9080 - val_loss: 1969.2163 - val_acc_pred: 0.9219
# Epoch 125/500
# HBox(children=(IntProgress(value=0, description='Epoch 124', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2247.6405 - acc_pred: 0.9080 - val_loss: 1967.0654 - val_acc_pred: 0.9220
# Epoch 126/500
# HBox(children=(IntProgress(value=0, description='Epoch 125', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2248.1549 - acc_pred: 0.9080 - val_loss: 1968.5303 - val_acc_pred: 0.9219
# Epoch 127/500
# HBox(children=(IntProgress(value=0, description='Epoch 126', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2246.8426 - acc_pred: 0.9081 - val_loss: 1969.0820 - val_acc_pred: 0.9219
# Epoch 128/500
# HBox(children=(IntProgress(value=0, description='Epoch 127', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 280s 9ms/step - loss: 2246.8160 - acc_pred: 0.9081 - val_loss: 1967.2491 - val_acc_pred: 0.9220
# Epoch 129/500
# HBox(children=(IntProgress(value=0, description='Epoch 128', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2247.5223 - acc_pred: 0.9080 - val_loss: 1967.5219 - val_acc_pred: 0.9220
# Epoch 130/500
# HBox(children=(IntProgress(value=0, description='Epoch 129', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 284s 9ms/step - loss: 2246.4643 - acc_pred: 0.9081 - val_loss: 1967.1992 - val_acc_pred: 0.9220
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# Epoch 131/500
# HBox(children=(IntProgress(value=0, description='Epoch 130', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 284s 9ms/step - loss: 2248.4259 - acc_pred: 0.9080 - val_loss: 1967.2223 - val_acc_pred: 0.9220
# Epoch 132/500
# HBox(children=(IntProgress(value=0, description='Epoch 131', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2248.7845 - acc_pred: 0.9080 - val_loss: 1968.2301 - val_acc_pred: 0.9219
# Epoch 133/500
# HBox(children=(IntProgress(value=0, description='Epoch 132', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2249.5042 - acc_pred: 0.9080 - val_loss: 1967.8417 - val_acc_pred: 0.9219
# Epoch 134/500
# HBox(children=(IntProgress(value=0, description='Epoch 133', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2246.9420 - acc_pred: 0.9081 - val_loss: 1968.1690 - val_acc_pred: 0.9219
# Epoch 135/500
# HBox(children=(IntProgress(value=0, description='Epoch 134', max=32000, style=ProgressStyle(description_width=…
# 32000/32000 [==============================] - 281s 9ms/step - loss: 2247.3736 - acc_pred: 0.9081 - val_loss: 1967.1095 - val_acc_pred: 0.9220
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 2.04800016945228e-06.

# %%
PlotHistory(model.history.history,listKeys=['val_loss','loss'],axis_=[0,100,1000,4000])
# Out:
# val_loss   :  [1967.22234375, 1968.2300712890626, 1967.8417333984376, 1968.1690087890624]
# loss   :  [2248.425937011719, 2248.7844609375, 2249.5042392578125, 2246.941957519531]

# %%
PlotHistory(model.history.history,listKeys=['lr'])
# Out:
# lr   :  [4.0960003e-06, 4.0960003e-06, 4.0960003e-06, 4.0960003e-06]

# %%
PlotHistory(model.history.history,listKeys=['val_acc_pred','acc_pred'])
# Out:
# val_acc_pred   :  [0.9219543232917785, 0.921947250366211, 0.9219455223083496, 0.9219209871292114]
# acc_pred   :  [0.9079893316030503, 0.9079840955734253, 0.9079533910751343, 0.9080531071424485]

# %%
x_rec=model.model.predict(x_test)
PlotDataAE(x_test[:,:,:,1],np.argmax(x_rec[:,:,:,:],axis=-1),digit_size=100)

# %%
x_gen=model.generate(binary=True)
PlotDataAE([],x_gen[:,:,:],digit_size=100,Only_Result=False)
